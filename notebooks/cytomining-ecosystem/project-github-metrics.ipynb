# %% [markdown]
# # Project Git Metrics for Landscape Analysis
#
# Project git metrics for software landscape analysis related to Cytomining ecosystem.
#
# ## Setup
#
# Set an environment variable named `LANDSCAPE_ANALYSIS_GH_TOKEN` to a [GitHub access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens). E.g.: `export LANDSCAPE_ANALYSIS_GH_TOKEN=token_here`

# %%
import os
from datetime import datetime

import pandas as pd
import pytz
from box import Box
from github import Auth, Github

# set github authorization and client
github_client = Github(
    auth=Auth.Token(os.environ.get("LANDSCAPE_ANALYSIS_GH_TOKEN")), per_page=100
)
# get the current datetime
tz = pytz.timezone("UTC")
current_datetime = datetime.now(tz)

# %%
# gather projects data
projects = Box.from_yaml(filename="data/projects.yaml").projects

# check the number of projects
print("number of projects: ", len(projects))
# Out:
# number of projects:  1239

# %%
# show the keys available for the projects
projects[0].keys()
# Out:
# dict_keys(['category', 'homepage_url', 'name', 'repo_url'])

# %%
def try_to_detect_license(repo):
    """
    Tries to detect the license from GitHub API
    """

    try:
        return repo.get_license().license.spdx_id
    except:
        return None

# %%
def try_to_gather_commit_count(repo):
    """
    Tries to detect commit count of repo from GitHub API
    """

    try:
        return len(list(repo.get_commits()))
    except:
        return 0

# %%
def try_to_gather_most_recent_commit_date(repo):
    """
    Tries to detect most recent commit date of repo from GitHub API
    """

    try:
        return repo.pushed_at.replace(tzinfo=pytz.UTC)
    except:
        return None

# %%
df_projects = pd.DataFrame(
    # create a list of repo data records for a dataframe
    [
        {
            "Project Name": repo.name,
            "GitHub Repository ID": repo.id,
            "Project Homepage": repo.homepage,
            "Project Repo URL": repo.html_url,
            "Project Landscape Category": project.category,
            "GitHub Stars": repo.stargazers_count,
            "GitHub Forks": repo.forks_count,
            "GitHub Subscribers": repo.subscribers_count,
            "GitHub Open Issues": repo.get_issues(state="open").totalCount,
            "GitHub Contributors": repo.get_contributors().totalCount,
            "GitHub License Type": try_to_detect_license(repo),
            "GitHub Description": repo.description,
            "GitHub Topics": repo.topics,
            # gather org name if it exists
            "GitHub Organization": repo.organization.login
            if repo.organization
            else None,
            "GitHub Network Count": repo.network_count,
            "GitHub Detected Languages": repo.get_languages(),
            "Date Created": repo.created_at.replace(tzinfo=pytz.UTC),
            "Date Most Recent Commit": try_to_gather_most_recent_commit_date(repo),
            # placeholders for later datetime calculations
            "Duration Created to Most Recent Commit": "",
            "Duration Created to Now": "",
            "Duration Most Recent Commit to Now": "",
            "Repository Size (KB)": repo.size,
            "GitHub Repo Archived": repo.archived,
        }
        # make a request for github repo data with pygithub
        for project, repo in [
            (
                project,
                github_client.get_repo(
                    project.repo_url.replace("https://github.com/", "")
                ),
            )
            for project in projects
        ]
    ]
)

# show the result
df_projects
# Out:
# Following Github server redirection from /repos/theislab/scanpy to /repositories/80342493
# Following Github server redirection from /repos/YosefLab/scvi-tools to /repositories/102567256
# Following Github server redirection from /repos/shenorrLab/bseqsc to /repositories/62131343
#                                            Project Name  GitHub Repository ID  \
# 0                                           pycytominer             195106954
# 1                                             CytoSnake             459692818
# 2                                             CytoTable             534282624
# 3                                            IDR_stream             523111118
# 4                                                pandas                858127
# ...                                                 ...                   ...
# 1234  Vaccine-associated-enhanced-respiratory-pathol...             492803234
# 1235               Marmoset_FetalBrain_singlecellRNAseq             484170652
# 1236    Myotome-volume-Nucleus-count-and-Color-analysis             482789058
# 1237                               thymus_spatial_atlas             634860333
# 1238                                     scRNAseq_PBMCs             274239203
#
#                              Project Homepage  \
# 0          https://pycytominer.readthedocs.io
# 1            https://cytosnake.readthedocs.io
# 2     https://cytomining.github.io/CytoTable/
# 3                                        None
# 4                   https://pandas.pydata.org
# ...                                       ...
# 1234                                     None
# 1235                                     None
# 1236
# 1237
# 1238
#
#                                        Project Repo URL  \
# 0             https://github.com/cytomining/pycytominer
# 1               https://github.com/WayScience/CytoSnake
# 2               https://github.com/cytomining/CytoTable
# 3              https://github.com/WayScience/IDR_stream
# 4                  https://github.com/pandas-dev/pandas
# ...                                                 ...
# 1234  https://github.com/Berlin-Hamster-Single-Cell-...
# 1235  https://github.com/parulvarma123/Marmoset_Feta...
# 1236  https://github.com/peggyscshu/Myotome-volume-N...
# 1237   https://github.com/Teichlab/thymus_spatial_atlas
# 1238          https://github.com/jwiarda/scRNAseq_PBMCs
#
#                        Project Landscape Category  GitHub Stars  GitHub Forks  \
# 0               [loi-focus, cytomining-ecosystem]            52            32
# 1               [loi-focus, cytomining-ecosystem]             3             3
# 2               [loi-focus, cytomining-ecosystem]             3             4
# 3               [loi-focus, cytomining-ecosystem]             4             2
# 4     [cytomining-ecosystem-relevant-open-source]         40031         16810
# ...                                           ...           ...           ...
# 1234          [related-tools-github-query-result]             1             0
# 1235          [related-tools-github-query-result]             1             0
# 1236          [related-tools-github-query-result]             1             0
# 1237          [related-tools-github-query-result]             1             0
# 1238          [related-tools-github-query-result]             1             1
#
#       GitHub Subscribers  GitHub Open Issues  GitHub Contributors  ...  \
# 0                      6                  83                   22  ...
# 1                      0                  35                    3  ...
# 2                      4                  41                    4  ...
# 3                      2                   2                    2  ...
# 4                   1121                3656                  411  ...
# ...                  ...                 ...                  ...  ...
# 1234                   0                   1                    1  ...
# 1235                   1                   0                    1  ...
# 1236                   1                   6                    1  ...
# 1237                   0                   0                    1  ...
# 1238                   3                   0                    2  ...
#
#                         GitHub Organization GitHub Network Count  \
# 0                                cytomining                   32
# 1                                WayScience                    3
# 2                                cytomining                    4
# 3                                WayScience                    2
# 4                                pandas-dev                16810
# ...                                     ...                  ...
# 1234  Berlin-Hamster-Single-Cell-Consortium                    0
# 1235                                   None                    0
# 1236                                   None                    0
# 1237                               Teichlab                    0
# 1238                                   None                    1
#
#                               GitHub Detected Languages  \
# 0     {'Python': 373578, 'Jupyter Notebook': 16489, ...
# 1                                    {'Python': 132842}
# 2                                    {'Python': 154533}
# 3         {'Jupyter Notebook': 311010, 'Python': 88583}
# 4     {'Python': 20324063, 'Cython': 1277513, 'HTML'...
# ...                                                 ...
# 1234                                       {'R': 47789}
# 1235                                       {'R': 18458}
# 1236             {'ImageJ Macro': 17729, 'Python': 807}
# 1237  {'Jupyter Notebook': 165406342, 'Python': 1268...
# 1238                                                 {}
#
#                   Date Created   Date Most Recent Commit  \
# 0    2019-07-03 18:22:51+00:00 2023-10-11 13:58:57+00:00
# 1    2022-02-15 18:02:45+00:00 2023-09-01 23:10:17+00:00
# 2    2022-09-08 15:46:25+00:00 2023-10-13 13:46:51+00:00
# 3    2022-08-09 21:16:48+00:00 2023-02-24 22:08:54+00:00
# 4    2010-08-24 01:37:33+00:00 2023-10-16 16:52:20+00:00
# ...                        ...                       ...
# 1234 2022-05-16 11:21:45+00:00 2022-07-17 10:27:24+00:00
# 1235 2022-04-21 18:56:18+00:00 2022-04-21 22:53:17+00:00
# 1236 2022-04-18 09:28:35+00:00 2022-04-27 08:42:53+00:00
# 1237 2023-05-01 11:53:13+00:00 2023-09-22 13:04:47+00:00
# 1238 2020-06-22 20:49:09+00:00 2021-05-20 21:00:49+00:00
#
#      Duration Created to Most Recent Commit Duration Created to Now  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...                     ...
# 1234
# 1235
# 1236
# 1237
# 1238
#
#      Duration Most Recent Commit to Now Repository Size (KB)  \
# 0                                                     721073
# 1                                                        780
# 2                                                       6829
# 3                                                      37026
# 4                                                     334787
# ...                                 ...                  ...
# 1234                                                      60
# 1235                                                       7
# 1236                                                     103
# 1237                                                  395652
# 1238                                                    4101
#
#      GitHub Repo Archived
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 1234                False
# 1235                False
# 1236                False
# 1237                False
# 1238                False
#
# [1239 rows x 23 columns]

# %%
# calculate time deltas
df_projects["Duration Created to Most Recent Commit"] = (
    df_projects["Date Most Recent Commit"] - df_projects["Date Created"]
)
df_projects["Duration Created to Now"] = current_datetime - df_projects["Date Created"]
df_projects["Duration Most Recent Commit to Now"] = (
    current_datetime - df_projects["Date Most Recent Commit"]
)

# create a years count for project time duration
df_projects["Duration Created to Now in Years"] = (
    df_projects["Duration Created to Now"].dt.days / 365
)

# show the result
df_projects
# Out:
#                                            Project Name  GitHub Repository ID  \
# 0                                           pycytominer             195106954
# 1                                             CytoSnake             459692818
# 2                                             CytoTable             534282624
# 3                                            IDR_stream             523111118
# 4                                                pandas                858127
# ...                                                 ...                   ...
# 1234  Vaccine-associated-enhanced-respiratory-pathol...             492803234
# 1235               Marmoset_FetalBrain_singlecellRNAseq             484170652
# 1236    Myotome-volume-Nucleus-count-and-Color-analysis             482789058
# 1237                               thymus_spatial_atlas             634860333
# 1238                                     scRNAseq_PBMCs             274239203
#
#                              Project Homepage  \
# 0          https://pycytominer.readthedocs.io
# 1            https://cytosnake.readthedocs.io
# 2     https://cytomining.github.io/CytoTable/
# 3                                        None
# 4                   https://pandas.pydata.org
# ...                                       ...
# 1234                                     None
# 1235                                     None
# 1236
# 1237
# 1238
#
#                                        Project Repo URL  \
# 0             https://github.com/cytomining/pycytominer
# 1               https://github.com/WayScience/CytoSnake
# 2               https://github.com/cytomining/CytoTable
# 3              https://github.com/WayScience/IDR_stream
# 4                  https://github.com/pandas-dev/pandas
# ...                                                 ...
# 1234  https://github.com/Berlin-Hamster-Single-Cell-...
# 1235  https://github.com/parulvarma123/Marmoset_Feta...
# 1236  https://github.com/peggyscshu/Myotome-volume-N...
# 1237   https://github.com/Teichlab/thymus_spatial_atlas
# 1238          https://github.com/jwiarda/scRNAseq_PBMCs
#
#                        Project Landscape Category  GitHub Stars  GitHub Forks  \
# 0               [loi-focus, cytomining-ecosystem]            52            32
# 1               [loi-focus, cytomining-ecosystem]             3             3
# 2               [loi-focus, cytomining-ecosystem]             3             4
# 3               [loi-focus, cytomining-ecosystem]             4             2
# 4     [cytomining-ecosystem-relevant-open-source]         40031         16810
# ...                                           ...           ...           ...
# 1234          [related-tools-github-query-result]             1             0
# 1235          [related-tools-github-query-result]             1             0
# 1236          [related-tools-github-query-result]             1             0
# 1237          [related-tools-github-query-result]             1             0
# 1238          [related-tools-github-query-result]             1             1
#
#       GitHub Subscribers  GitHub Open Issues  GitHub Contributors  ...  \
# 0                      6                  83                   22  ...
# 1                      0                  35                    3  ...
# 2                      4                  41                    4  ...
# 3                      2                   2                    2  ...
# 4                   1121                3656                  411  ...
# ...                  ...                 ...                  ...  ...
# 1234                   0                   1                    1  ...
# 1235                   1                   0                    1  ...
# 1236                   1                   6                    1  ...
# 1237                   0                   0                    1  ...
# 1238                   3                   0                    2  ...
#
#      GitHub Network Count                          GitHub Detected Languages  \
# 0                      32  {'Python': 373578, 'Jupyter Notebook': 16489, ...
# 1                       3                                 {'Python': 132842}
# 2                       4                                 {'Python': 154533}
# 3                       2      {'Jupyter Notebook': 311010, 'Python': 88583}
# 4                   16810  {'Python': 20324063, 'Cython': 1277513, 'HTML'...
# ...                   ...                                                ...
# 1234                    0                                       {'R': 47789}
# 1235                    0                                       {'R': 18458}
# 1236                    0             {'ImageJ Macro': 17729, 'Python': 807}
# 1237                    0  {'Jupyter Notebook': 165406342, 'Python': 1268...
# 1238                    1                                                 {}
#
#                   Date Created   Date Most Recent Commit  \
# 0    2019-07-03 18:22:51+00:00 2023-10-11 13:58:57+00:00
# 1    2022-02-15 18:02:45+00:00 2023-09-01 23:10:17+00:00
# 2    2022-09-08 15:46:25+00:00 2023-10-13 13:46:51+00:00
# 3    2022-08-09 21:16:48+00:00 2023-02-24 22:08:54+00:00
# 4    2010-08-24 01:37:33+00:00 2023-10-16 16:52:20+00:00
# ...                        ...                       ...
# 1234 2022-05-16 11:21:45+00:00 2022-07-17 10:27:24+00:00
# 1235 2022-04-21 18:56:18+00:00 2022-04-21 22:53:17+00:00
# 1236 2022-04-18 09:28:35+00:00 2022-04-27 08:42:53+00:00
# 1237 2023-05-01 11:53:13+00:00 2023-09-22 13:04:47+00:00
# 1238 2020-06-22 20:49:09+00:00 2021-05-20 21:00:49+00:00
#
#       Duration Created to Most Recent Commit   Duration Created to Now  \
# 0                         1560 days 19:36:06 1565 days 22:59:56.559263
# 1                          563 days 05:07:32  607 days 23:20:02.559263
# 2                          399 days 22:00:26  403 days 01:36:22.559263
# 3                          199 days 00:52:06  432 days 20:05:59.559263
# 4                         4801 days 15:14:47 4801 days 15:45:14.559263
# ...                                      ...                       ...
# 1234                        61 days 23:05:39  518 days 06:01:02.559263
# 1235                         0 days 03:56:59  542 days 22:26:29.559263
# 1236                         8 days 23:14:18  546 days 07:54:12.559263
# 1237                       144 days 01:11:34  168 days 05:29:34.559263
# 1238                       332 days 00:11:40 1210 days 20:33:38.559263
#
#      Duration Most Recent Commit to Now Repository Size (KB)  \
# 0                5 days 03:23:50.559263               721073
# 1               44 days 18:12:30.559263                  780
# 2                3 days 03:35:56.559263                 6829
# 3              233 days 19:13:53.559263                37026
# 4                0 days 00:30:27.559263               334787
# ...                                 ...                  ...
# 1234           456 days 06:55:23.559263                   60
# 1235           542 days 18:29:30.559263                    7
# 1236           537 days 08:39:54.559263                  103
# 1237            24 days 04:18:00.559263               395652
# 1238           878 days 20:21:58.559263                 4101
#
#      GitHub Repo Archived Duration Created to Now in Years
# 0                   False                         4.287671
# 1                   False                         1.663014
# 2                   False                         1.104110
# 3                   False                         1.183562
# 4                   False                        13.153425
# ...                   ...                              ...
# 1234                False                         1.419178
# 1235                False                         1.484932
# 1236                False                         1.495890
# 1237                False                         0.460274
# 1238                False                         3.315068
#
# [1239 rows x 24 columns]

# %%
# filter the results
df_projects = df_projects[
    # filter projects which are < 50 KB
    df_projects["Repository Size (KB)"]
    >= 50
    # filter projects which have been archived
    & ~df_projects["GitHub Repo Archived"]
][  # filter projects which have no detected programming languages
    df_projects["GitHub Detected Languages"].str.len()
    > 0
    # Drop duplicates based on github repository id
].drop_duplicates(
    subset="GitHub Repository ID"
)
df_projects.tail()
# Out:
#                                            Project Name  GitHub Repository ID  \
# 1232                                     GeneExpressMap                925122
# 1234  Vaccine-associated-enhanced-respiratory-pathol...             492803234
# 1235               Marmoset_FetalBrain_singlecellRNAseq             484170652
# 1236    Myotome-volume-Nucleus-count-and-Color-analysis             482789058
# 1237                               thymus_spatial_atlas             634860333
#
#      Project Homepage                                   Project Repo URL  \
# 1232                        https://github.com/coreyflynn/GeneExpressMap
# 1234             None  https://github.com/Berlin-Hamster-Single-Cell-...
# 1235             None  https://github.com/parulvarma123/Marmoset_Feta...
# 1236                   https://github.com/peggyscshu/Myotome-volume-N...
# 1237                    https://github.com/Teichlab/thymus_spatial_atlas
#
#                Project Landscape Category  GitHub Stars  GitHub Forks  \
# 1232  [related-tools-github-query-result]             1             0
# 1234  [related-tools-github-query-result]             1             0
# 1235  [related-tools-github-query-result]             1             0
# 1236  [related-tools-github-query-result]             1             0
# 1237  [related-tools-github-query-result]             1             0
#
#       GitHub Subscribers  GitHub Open Issues  GitHub Contributors  ...  \
# 1232                   2                   0                    1  ...
# 1234                   0                   1                    1  ...
# 1235                   1                   0                    1  ...
# 1236                   1                   6                    1  ...
# 1237                   0                   0                    1  ...
#
#      GitHub Network Count                          GitHub Detected Languages  \
# 1232                    0                            {'Objective-C': 166172}
# 1234                    0                                       {'R': 47789}
# 1235                    0                                       {'R': 18458}
# 1236                    0             {'ImageJ Macro': 17729, 'Python': 807}
# 1237                    0  {'Jupyter Notebook': 165406342, 'Python': 1268...
#
#                   Date Created   Date Most Recent Commit  \
# 1232 2010-09-20 14:58:40+00:00 2011-06-21 13:44:00+00:00
# 1234 2022-05-16 11:21:45+00:00 2022-07-17 10:27:24+00:00
# 1235 2022-04-21 18:56:18+00:00 2022-04-21 22:53:17+00:00
# 1236 2022-04-18 09:28:35+00:00 2022-04-27 08:42:53+00:00
# 1237 2023-05-01 11:53:13+00:00 2023-09-22 13:04:47+00:00
#
#       Duration Created to Most Recent Commit   Duration Created to Now  \
# 1232                       273 days 22:45:20 4774 days 02:24:07.559263
# 1234                        61 days 23:05:39  518 days 06:01:02.559263
# 1235                         0 days 03:56:59  542 days 22:26:29.559263
# 1236                         8 days 23:14:18  546 days 07:54:12.559263
# 1237                       144 days 01:11:34  168 days 05:29:34.559263
#
#      Duration Most Recent Commit to Now Repository Size (KB)  \
# 1232          4500 days 03:38:47.559263                 1052
# 1234           456 days 06:55:23.559263                   60
# 1235           542 days 18:29:30.559263                    7
# 1236           537 days 08:39:54.559263                  103
# 1237            24 days 04:18:00.559263               395652
#
#      GitHub Repo Archived Duration Created to Now in Years
# 1232                False                        13.079452
# 1234                False                         1.419178
# 1235                False                         1.484932
# 1236                False                         1.495890
# 1237                False                         0.460274
#
# [5 rows x 24 columns]

# %%
# negate this duration value for sorting descendingly,
# with projects that have been more recently changed sorting to the top
df_projects["Negative Duration Most Recent Commit to Now"] = -df_projects[
    "Duration Most Recent Commit to Now"
]
df_projects = df_projects.sort_values(
    by=[
        "GitHub Stars",
        "GitHub Subscribers",
        "GitHub Contributors",
        "GitHub Forks",
        "GitHub Open Issues",
        "Negative Duration Most Recent Commit to Now",
        "Duration Created to Most Recent Commit",
    ],
    ascending=False,
)
df_projects
# Out:
#                                         Project Name  GitHub Repository ID  \
# 4                                             pandas                858127
# 5                                              numpy                908607
# 14                                             arrow              51905353
# 16                                            duckdb             138754790
# 15                                        parquet-mr              20675636
# ..                                               ...                   ...
# 151                                     ImagingCells             137526283
# 224                                       course-bia             119301640
# 156  Cell-virulence-Detection-using-Image-Processing             163268436
# 160                                   Image-analysis             152904377
# 225                               oct-image-analysis             125785309
#
#               Project Homepage  \
# 4    https://pandas.pydata.org
# 5            https://numpy.org
# 14   https://arrow.apache.org/
# 16       http://www.duckdb.org
# 15
# ..                         ...
# 151                       None
# 224                       None
# 156                       None
# 160
# 225
#
#                                       Project Repo URL  \
# 4                 https://github.com/pandas-dev/pandas
# 5                       https://github.com/numpy/numpy
# 14                     https://github.com/apache/arrow
# 16                    https://github.com/duckdb/duckdb
# 15                https://github.com/apache/parquet-mr
# ..                                                 ...
# 151           https://github.com/jesnyder/ImagingCells
# 224                https://github.com/denzf/course-bia
# 156  https://github.com/arushigupta148/Cell-virulen...
# 160            https://github.com/dguin/Image-analysis
# 225   https://github.com/ricster101/oct-image-analysis
#
#                       Project Landscape Category  GitHub Stars  GitHub Forks  \
# 4    [cytomining-ecosystem-relevant-open-source]         40031         16810
# 5    [cytomining-ecosystem-relevant-open-source]         24741          8647
# 14   [cytomining-ecosystem-relevant-open-source]         12614          3096
# 16   [cytomining-ecosystem-relevant-open-source]         12393          1157
# 15   [cytomining-ecosystem-relevant-open-source]          2179          1332
# ..                                           ...           ...           ...
# 151          [related-tools-github-query-result]             0             0
# 224          [related-tools-github-query-result]             0             0
# 156          [related-tools-github-query-result]             0             0
# 160          [related-tools-github-query-result]             0             0
# 225          [related-tools-github-query-result]             0             0
#
#      GitHub Subscribers  GitHub Open Issues  GitHub Contributors  ...  \
# 4                  1121                3656                  411  ...
# 5                   595                2193                  435  ...
# 14                  351                3908                  367  ...
# 16                  157                 309                  253  ...
# 15                   95                 130                  190  ...
# ..                  ...                 ...                  ...  ...
# 151                   1                   0                    1  ...
# 224                   1                   0                    1  ...
# 156                   0                   0                    1  ...
# 160                   0                   0                    1  ...
# 225                   0                   0                    1  ...
#
#                              GitHub Detected Languages  \
# 4    {'Python': 20324063, 'Cython': 1277513, 'HTML'...
# 5    {'Python': 10458450, 'C': 6220071, 'C++': 2057...
# 14   {'C++': 26864997, 'Java': 7353737, 'Go': 56198...
# 16   {'C++': 33576510, 'C': 1761733, 'Python': 1407...
# 15   {'Java': 5923431, 'Shell': 14860, 'Python': 14...
# ..                                                 ...
# 151                         {'Jupyter Notebook': 1523}
# 224                                   {'Python': 6010}
# 156                                  {'Python': 12989}
# 160                                  {'MATLAB': 40670}
# 225                                  {'MATLAB': 22755}
#
#                  Date Created   Date Most Recent Commit  \
# 4   2010-08-24 01:37:33+00:00 2023-10-16 16:52:20+00:00
# 5   2010-09-13 23:02:39+00:00 2023-10-16 14:25:39+00:00
# 14  2016-02-17 08:00:23+00:00 2023-10-16 17:18:03+00:00
# 16  2018-06-26 15:04:45+00:00 2023-10-16 14:58:09+00:00
# 15  2014-06-10 07:00:07+00:00 2023-10-16 15:19:17+00:00
# ..                        ...                       ...
# 151 2018-06-15 19:50:00+00:00 2018-08-31 19:21:33+00:00
# 224 2018-01-28 21:58:13+00:00 2018-01-24 03:22:19+00:00
# 156 2018-12-27 08:27:06+00:00 2019-05-12 23:09:02+00:00
# 160 2018-10-13 18:53:42+00:00 2018-10-13 19:32:22+00:00
# 225 2018-03-19 01:29:32+00:00 2018-03-19 03:31:25+00:00
#
#     Duration Created to Most Recent Commit   Duration Created to Now  \
# 4                       4801 days 15:14:47 4801 days 15:45:14.559263
# 5                       4780 days 15:23:00 4780 days 18:20:08.559263
# 14                      2798 days 09:17:40 2798 days 09:22:24.559263
# 16                      1937 days 23:53:24 1938 days 02:18:02.559263
# 15                      3415 days 08:19:10 3415 days 10:22:40.559263
# ..                                     ...                       ...
# 151                       76 days 23:31:33 1948 days 21:32:47.559263
# 224                      -5 days +05:24:06 2086 days 19:24:34.559263
# 156                      136 days 14:41:56 1754 days 08:55:41.559263
# 160                        0 days 00:38:40 1828 days 22:29:05.559263
# 225                        0 days 02:01:53 2037 days 15:53:15.559263
#
#     Duration Most Recent Commit to Now Repository Size (KB)  \
# 4               0 days 00:30:27.559263               334787
# 5               0 days 02:57:08.559263               131902
# 14              0 days 00:04:44.559263               171101
# 16              0 days 02:24:38.559263               227662
# 15              0 days 02:03:30.559263                18475
# ..                                 ...                  ...
# 151          1871 days 22:01:14.559263                    1
# 224          2091 days 14:00:28.559263                  203
# 156          1617 days 18:13:45.559263                 1751
# 160          1828 days 21:50:25.559263                   26
# 225          2037 days 13:51:22.559263                   16
#
#     GitHub Repo Archived Duration Created to Now in Years  \
# 4                  False                        13.153425
# 5                  False                        13.095890
# 14                 False                         7.665753
# 16                 False                         5.309589
# 15                 False                         9.356164
# ..                   ...                              ...
# 151                False                         5.336986
# 224                False                         5.715068
# 156                False                         4.805479
# 160                False                         5.008219
# 225                False                         5.580822
#
#     Negative Duration Most Recent Commit to Now
# 4                      -1 days +23:29:32.440737
# 5                      -1 days +21:02:51.440737
# 14                     -1 days +23:55:15.440737
# 16                     -1 days +21:35:21.440737
# 15                     -1 days +21:56:29.440737
# ..                                          ...
# 151                 -1872 days +01:58:45.440737
# 224                 -2092 days +09:59:31.440737
# 156                 -1618 days +05:46:14.440737
# 160                 -1829 days +02:09:34.440737
# 225                 -2038 days +10:08:37.440737
#
# [1123 rows x 25 columns]

# %%
# export to parquet for later use
df_projects.to_parquet("data/project-github-metrics.parquet")
