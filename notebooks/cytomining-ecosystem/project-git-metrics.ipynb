# %% [markdown]
# # Project Git Metrics for Landscape Analysis
#
# Project git metrics for software landscape analysis related to Cytomining ecosystem.
#
# ## Setup
#
# Set an environment variable named `LANDSCAPE_ANALYSIS_GH_TOKEN` to a [GitHub access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens). E.g.: `export LANDSCAPE_ANALYSIS_GH_TOKEN=token_here`

# %%
import os
from datetime import datetime

import pandas as pd
import pytz
from box import Box
from github import Auth, Github

# set github authorization and client
github_client = Github(
    auth=Auth.Token(os.environ.get("LANDSCAPE_ANALYSIS_GH_TOKEN")), per_page=100
)
# get the current datetime
tz = pytz.timezone("UTC")
current_datetime = datetime.now(tz)

# %%
# gather projects data
projects = Box.from_yaml(filename="data/projects.yaml").projects

# check the number of projects
print("number of projects: ", len(projects))
# Out:
# number of projects:  1239

# %%
# show the keys available for the projects
projects[0].keys()
# Out:
# dict_keys(['category', 'homepage_url', 'name', 'repo_url'])

# %%
def try_to_detect_license(repo):
    """
    Tries to detect the license from GitHub API
    """

    try:
        return repo.get_license().license.spdx_id
    except:
        return None

# %%
def try_to_gather_commit_count(repo):
    """
    Tries to detect commit count of repo from GitHub API
    """

    try:
        return len(list(repo.get_commits()))
    except:
        return 0

# %%
def try_to_gather_most_recent_commit_date(repo):
    """
    Tries to detect most recent commit date of repo from GitHub API
    """

    try:
        return repo.pushed_at.replace(tzinfo=pytz.UTC)
    except:
        return None

# %%
df_projects = pd.DataFrame(
    # create a list of repo data records for a dataframe
    [
        {
            "Project Name": repo.name,
            "Project Homepage": repo.homepage,
            "Project Repo URL": repo.html_url,
            "Project Landscape Category": project.category,
            "GitHub Stars": repo.stargazers_count,
            "GitHub Forks": repo.forks_count,
            "GitHub Watchers": repo.subscribers_count,
            "GitHub Open Issues": repo.get_issues(state="open").totalCount,
            "GitHub Contributors": repo.get_contributors().totalCount,
            "GitHub License Type": try_to_detect_license(repo),
            "GitHub Description": repo.description,
            "GitHub Topics": repo.topics,
            "GitHub Detected Languages": repo.get_languages(),
            "Date Created": repo.created_at.replace(tzinfo=pytz.UTC),
            "Date Most Recent Commit": try_to_gather_most_recent_commit_date(repo),
            # placeholders for later datetime calculations
            "Duration Created to Most Recent Commit": "",
            "Duration Created to Now": "",
            "Duration Most Recent Commit to Now": "",
            "Repository Size (KB)": repo.size,
            "GitHub Repo Archived": repo.archived,
        }
        # make a request for github repo data with pygithub
        for project, repo in [
            (
                project,
                github_client.get_repo(
                    project.repo_url.replace("https://github.com/", "")
                ),
            )
            for project in projects
        ]
    ]
)

# calculate time deltas
df_projects["Duration Created to Most Recent Commit"] = (
    df_projects["Date Most Recent Commit"] - df_projects["Date Created"]
)
df_projects["Duration Created to Now"] = current_datetime - df_projects["Date Created"]
df_projects["Duration Most Recent Commit to Now"] = (
    current_datetime - df_projects["Date Most Recent Commit"]
)

# show the result
df_projects
# Out:
# Following Github server redirection from /repos/theislab/scanpy to /repositories/80342493
# Following Github server redirection from /repos/YosefLab/scvi-tools to /repositories/102567256
# Following Github server redirection from /repos/shenorrLab/bseqsc to /repositories/62131343
# Request GET /repos/Teichlab/sctkr/languages failed with 403: Forbidden
# Setting next backoff to 1528.109756s
#                                          Project Name  \
# 0                                         pycytominer
# 1                                           CytoSnake
# 2                                           CytoTable
# 3                                          IDR_stream
# 4                                              pandas
# ...                                               ...
# 1234             Marmoset_FetalBrain_singlecellRNAseq
# 1235  Myotome-volume-Nucleus-count-and-Color-analysis
# 1236                                   scRNAseq_PBMCs
# 1237                             thymus_spatial_atlas
# 1238                                         scMultiR
#
#                              Project Homepage  \
# 0          https://pycytominer.readthedocs.io
# 1            https://cytosnake.readthedocs.io
# 2     https://cytomining.github.io/CytoTable/
# 3                                        None
# 4                   https://pandas.pydata.org
# ...                                       ...
# 1234                                     None
# 1235
# 1236
# 1237
# 1238
#
#                                        Project Repo URL  \
# 0             https://github.com/cytomining/pycytominer
# 1               https://github.com/WayScience/CytoSnake
# 2               https://github.com/cytomining/CytoTable
# 3              https://github.com/WayScience/IDR_stream
# 4                  https://github.com/pandas-dev/pandas
# ...                                                 ...
# 1234  https://github.com/parulvarma123/Marmoset_Feta...
# 1235  https://github.com/peggyscshu/Myotome-volume-N...
# 1236          https://github.com/jwiarda/scRNAseq_PBMCs
# 1237   https://github.com/Teichlab/thymus_spatial_atlas
# 1238                 https://github.com/tagtag/scMultiR
#
#                        Project Landscape Category  GitHub Stars  GitHub Forks  \
# 0               [loi-focus, cytomining-ecosystem]            52            32
# 1               [loi-focus, cytomining-ecosystem]             3             3
# 2               [loi-focus, cytomining-ecosystem]             3             4
# 3               [loi-focus, cytomining-ecosystem]             4             2
# 4     [cytomining-ecosystem-relevant-open-source]         40001         16798
# ...                                           ...           ...           ...
# 1234          [related-tools-github-query-result]             1             0
# 1235          [related-tools-github-query-result]             1             0
# 1236          [related-tools-github-query-result]             1             1
# 1237          [related-tools-github-query-result]             1             0
# 1238          [related-tools-github-query-result]             1             1
#
#       GitHub Watchers  GitHub Open Issues  GitHub Contributors  \
# 0                   6                  83                   22
# 1                   0                  35                    3
# 2                   4                  41                    4
# 3                   2                   2                    2
# 4                1121                3640                  411
# ...               ...                 ...                  ...
# 1234                1                   0                    1
# 1235                1                   6                    1
# 1236                3                   0                    2
# 1237                0                   0                    1
# 1238                3                   0                    1
#
#      GitHub License Type                                 GitHub Description  \
# 0           BSD-3-Clause  Python package for processing image-based prof...
# 1              CC-BY-4.0  Orchestrating high-dimensional cell morphology...
# 2           BSD-3-Clause  Transform data for processing image-based prof...
# 3           BSD-3-Clause  Software for feature extraction from IDR image...
# 4           BSD-3-Clause  Flexible and powerful data analysis / manipula...
# ...                  ...                                                ...
# 1234                None  This repository contains scripts that have bee...
# 1235          Apache-2.0  The tools in this repository are designed to a...
# 1236                None  Scripts & figures used to finish scRNA-seq ana...
# 1237                None  general repo that holds all analysis and figur...
# 1238                None  This is a R source code by which we can perfor...
#
#                                           GitHub Topics  \
# 0     [carpenter-lab, cellprofiler, cytominer, image...
# 1     [cell-morphology, microscopy-images, pipeline,...
# 2     [cellprofiler, python, single-cell-analysis, w...
# 3                                                    []
# 4     [alignment, data-analysis, data-science, flexi...
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 1234                 False
# 1235                 False
# 1236                 False
# 1237                 False
# 1238                 False
#
# [1239 rows x 20 columns]

# %%
# filter the results
df_projects = df_projects[
    # filter projects which are < 50 KB
    df_projects["Repository Size (KB)"]
    >= 50
    # filter projects which have been archived
    & ~df_projects["GitHub Repo Archived"]
][  # filter projects which have no detected programming languages
    df_projects["GitHub Detected Languages"].str.len() > 0
]
df_projects.tail()
# Out:
#                                            Project Name Project Homepage  \
# 1233  Vaccine-associated-enhanced-respiratory-pathol...             None
# 1234               Marmoset_FetalBrain_singlecellRNAseq             None
# 1235    Myotome-volume-Nucleus-count-and-Color-analysis
# 1237                               thymus_spatial_atlas
# 1238                                           scMultiR
#
#                                        Project Repo URL  \
# 1233  https://github.com/Berlin-Hamster-Single-Cell-...
# 1234  https://github.com/parulvarma123/Marmoset_Feta...
# 1235  https://github.com/peggyscshu/Myotome-volume-N...
# 1237   https://github.com/Teichlab/thymus_spatial_atlas
# 1238                 https://github.com/tagtag/scMultiR
#
#                Project Landscape Category  GitHub Stars  GitHub Forks  \
# 1233  [related-tools-github-query-result]             1             0
# 1234  [related-tools-github-query-result]             1             0
# 1235  [related-tools-github-query-result]             1             0
# 1237  [related-tools-github-query-result]             1             0
# 1238  [related-tools-github-query-result]             1             1
#
#       GitHub Watchers  GitHub Open Issues  GitHub Contributors  \
# 1233                0                   1                    1
# 1234                1                   0                    1
# 1235                1                   6                    1
# 1237                0                   0                    1
# 1238                3                   0                    1
#
#      GitHub License Type                                 GitHub Description  \
# 1233             GPL-3.0  This is the GitHub repository providing access...
# 1234                None  This repository contains scripts that have bee...
# 1235          Apache-2.0  The tools in this repository are designed to a...
# 1237                None  general repo that holds all analysis and figur...
# 1238                None  This is a R source code by which we can perfor...
#
#                                           GitHub Topics  \
# 1233                                                 []
# 1234                                                 []
# 1235                                                 []
# 1237  [bioinformatics-tool, common-coordinate-framwo...
# 1238                                                 []
#
#                               GitHub Detected Languages  \
# 1233                                       {'R': 47789}
# 1234                                       {'R': 18458}
# 1235             {'ImageJ Macro': 17729, 'Python': 807}
# 1237  {'Jupyter Notebook': 165406342, 'Python': 1268...
# 1238                                       {'R': 31551}
#
#                   Date Created   Date Most Recent Commit  \
# 1233 2022-05-16 11:21:45+00:00 2022-07-17 10:27:24+00:00
# 1234 2022-04-21 18:56:18+00:00 2022-04-21 22:53:17+00:00
# 1235 2022-04-18 09:28:35+00:00 2022-04-27 08:42:53+00:00
# 1237 2023-05-01 11:53:13+00:00 2023-09-22 13:04:47+00:00
# 1238 2021-09-12 13:13:07+00:00 2022-04-09 23:23:44+00:00
#
#      Duration Created to Most Recent Commit  Duration Created to Now  \
# 1233                       61 days 23:05:39 515 days 08:42:18.235293
# 1234                        0 days 03:56:59 540 days 01:07:45.235293
# 1235                        8 days 23:14:18 543 days 10:35:28.235293
# 1237                      144 days 01:11:34 165 days 08:10:50.235293
# 1238                      209 days 10:10:37 761 days 06:50:56.235293
#
#      Duration Most Recent Commit to Now  Repository Size (KB)  \
# 1233           453 days 09:36:39.235293                    60
# 1234           539 days 21:10:46.235293                     7
# 1235           534 days 11:21:10.235293                   103
# 1237            21 days 06:59:16.235293                395652
# 1238           551 days 20:40:19.235293                    24
#
#       GitHub Repo Archived
# 1233                 False
# 1234                 False
# 1235                 False
# 1237                 False
# 1238                 False

# %%
# negate this duration value for sorting descendingly,
# with projects that have been more recently changed sorting to the top
df_projects["Negative Duration Most Recent Commit to Now"] = -df_projects[
    "Duration Most Recent Commit to Now"
]
df_projects = df_projects.sort_values(
    by=[
        "GitHub Stars",
        "GitHub Watchers",
        "GitHub Contributors",
        "GitHub Forks",
        "GitHub Open Issues",
        "Negative Duration Most Recent Commit to Now",
        "Duration Created to Most Recent Commit",
    ],
    ascending=False,
)
df_projects
# Out:
#                                         Project Name  \
# 4                                             pandas
# 5                                              numpy
# 14                                             arrow
# 16                                            duckdb
# 15                                        parquet-mr
# ..                                               ...
# 151                                     ImagingCells
# 224                                       course-bia
# 156  Cell-virulence-Detection-using-Image-Processing
# 160                                   Image-analysis
# 225                               oct-image-analysis
#
#               Project Homepage  \
# 4    https://pandas.pydata.org
# 5            https://numpy.org
# 14   https://arrow.apache.org/
# 16       http://www.duckdb.org
# 15
# ..                         ...
# 151                       None
# 224                       None
# 156                       None
# 160
# 225
#
#                                       Project Repo URL  \
# 4                 https://github.com/pandas-dev/pandas
# 5                       https://github.com/numpy/numpy
# 14                     https://github.com/apache/arrow
# 16                    https://github.com/duckdb/duckdb
# 15                https://github.com/apache/parquet-mr
# ..                                                 ...
# 151           https://github.com/jesnyder/ImagingCells
# 224                https://github.com/denzf/course-bia
# 156  https://github.com/arushigupta148/Cell-virulen...
# 160            https://github.com/dguin/Image-analysis
# 225   https://github.com/ricster101/oct-image-analysis
#
#                       Project Landscape Category  GitHub Stars  GitHub Forks  \
# 4    [cytomining-ecosystem-relevant-open-source]         40001         16798
# 5    [cytomining-ecosystem-relevant-open-source]         24720          8644
# 14   [cytomining-ecosystem-relevant-open-source]         12603          3094
# 16   [cytomining-ecosystem-relevant-open-source]         12351          1154
# 15   [cytomining-ecosystem-relevant-open-source]          2176          1332
# ..                                           ...           ...           ...
# 151          [related-tools-github-query-result]             0             0
# 224          [related-tools-github-query-result]             0             0
# 156          [related-tools-github-query-result]             0             0
# 160          [related-tools-github-query-result]             0             0
# 225          [related-tools-github-query-result]             0             0
#
#      GitHub Watchers  GitHub Open Issues  GitHub Contributors  \
# 4               1121                3640                  411
# 5                595                2196                  435
# 14               351                3902                  366
# 16               156                 321                  253
# 15                95                 130                  189
# ..               ...                 ...                  ...
# 151                1                   0                    1
# 224                1                   0                    1
# 156                0                   0                    1
# 160                0                   0                    1
# 225                0                   0                    1
#
#     GitHub License Type  ...  \
# 4          BSD-3-Clause  ...
# 5          BSD-3-Clause  ...
# 14           Apache-2.0  ...
# 16                  MIT  ...
# 15           Apache-2.0  ...
# ..                  ...  ...
# 151                None  ...
# 224                 MIT  ...
# 156                None  ...
# 160                None  ...
# 225                None  ...
#
#                                          GitHub Topics  \
# 4    [alignment, data-analysis, data-science, flexi...
# 5                                      [numpy, python]
# 14                                             [arrow]
# 16   [analytics, database, embedded-database, olap,...
# 15                           [big-data, java, parquet]
# ..                                                 ...
# 151                                                 []
# 224                                                 []
# 156                                                 []
# 160                                                 []
# 225                                                 []
#
#                              GitHub Detected Languages  \
# 4    {'Python': 20322774, 'Cython': 1277471, 'HTML'...
# 5    {'Python': 10457640, 'C': 6220070, 'C++': 2057...
